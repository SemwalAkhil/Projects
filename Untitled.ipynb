# %%
import pandas as pd

df = pd.read_csv(r'D:\Projects\Python\newProject\data.csv')

# %%
df
# Out:
#            Team 1        Team 2        Winner      Margin         Ground  \
# 0         England     Sri Lanka             -           -     Manchester
# 1        Pakistan    Bangladesh             -           -     Rawalpindi
# 2     West Indies  South Africa  South Africa     40 runs     Providence
# 3     West Indies  South Africa         drawn           -  Port of Spain
# 4         England   West Indies       England  10 wickets     Birmingham
# ...           ...           ...           ...         ...            ...
# 4246         Heat         Stars         Stars      8 runs       Brisbane
# 4247    Scorchers    Hurricanes    Hurricanes     31 runs          Perth
# 4248     Strikers     Renegades      Strikers     67 runs       Adelaide
# 4249        Stars       Thunder       Thunder   6 wickets      Melbourne
# 4250       Sixers          Heat        Sixers   7 wickets         Sydney
#
#            Match Date    Scorecard
# 0     Aug 21-25, 2024         Test
# ...

# %%
df.drop_duplicates(["Scorecard])
